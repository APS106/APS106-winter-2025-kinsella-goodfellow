# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 10 | Lecture 2 (10.2) - Jeopardy

# %%
import utils

# %%
scores = {
    'mechanical': sum([-1000, -1000]),
    'chemical': sum([-1000, -1000, 1000, 1000, 750, -500]),
    'civil': sum([-1000, 1000, -1000, -1000, -1000, -1000, -1000,-1000, 1000, -1000, 1000, 500, 750, 750]),
    'mineral': sum([]),
    'materials': sum([]),
    'industrial': sum([]),
    'track1': sum([-1000])
}

utils.plot_scores(scores)

# %%
class MyClass:
    def __init__(self):
        self.num = 0
        
    def set_num(self, num):
        self.num = num

# %%
seb = [1, 2, 3]

ob = MyClass()
ob.set_num(seb)
print(ob.num)
# Out:
# [1, 2, 3]

# %%
seb.append(10)

# %%
print(ob.num)
# Out:
# [1, 2, 3, 10]
