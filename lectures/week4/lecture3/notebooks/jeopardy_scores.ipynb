# %% [markdown]
# # APS106 - Fundamentals of Computer Programming
# ## Week 4 | Lecture 3 (4.3) - Jeopardy

# %%
import utils

# %%
scores = {
    'mechanical': sum([-500, 500, 500, 1000, 750, 1000, -250, -250, -250]),
    'chemical': sum([-500, -750, -250, -250]),
    'civil': sum([500, 1000, 1000, -250, 250, 250, -250, -250]),
    'mineral': sum([]),
    'materials': sum([]),
    'industrial': sum([-250, 250]),
    'track1': sum([])
}

utils.plot_scores(scores)
